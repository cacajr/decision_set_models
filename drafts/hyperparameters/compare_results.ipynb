# %% [markdown]
# # Imports

# %%
import sys, os
if not sys.path[0] == os.path.abspath('../..'):
    sys.path.insert(0, os.path.abspath('../..'))

from drafts.hyperparameters.utils import show_results_cv, show_results_ho

# %% [markdown]
# # IMLIB vs DI-IMLIB vs Decision Tree (Cross Validation)

# %%
show_results_cv(
    ['imlib', 'diimlib', 'decision_tree'], 
    ['lung_cancer', 'iris', 'parkinsons','ionosphere','wdbc', 'transfusion', 'pima', 'titanic', 'depressed', 'mushroom']
)
# Out:
#        Datasets         Models Number of rules          |R| Largest rule size  \
# 0   lung_cancer          imlib     3.00 ± 0.00  3.20 ± 0.41       1.20 ± 0.41
# 1   lung_cancer        diimlib     1.27 ± 0.46  2.60 ± 1.18       2.13 ± 0.74
# 2   lung_cancer  decision_tree     2.00 ± 0.00  2.00 ± 0.00       1.00 ± 0.00
# 3          iris          imlib     1.00 ± 0.00  2.87 ± 0.74       2.87 ± 0.74
# 4          iris        diimlib     2.27 ± 0.80  6.60 ± 2.56       3.27 ± 0.46
# 5          iris  decision_tree     4.00 ± 0.00  9.00 ± 0.00       3.00 ± 0.00
# 6    parkinsons          imlib     2.00 ± 0.00  2.00 ± 0.00       1.00 ± 0.00
# 7    parkinsons        diimlib     2.27 ± 1.10  5.67 ± 3.68       2.93 ± 0.80
# 8    parkinsons  decision_tree     4.00 ± 0.00  8.00 ± 0.00       2.00 ± 0.00
# 9    ionosphere          imlib     1.00 ± 0.00  2.00 ± 0.00       2.00 ± 0.00
# 10   ionosphere        diimlib     1.47 ± 0.64  4.27 ± 1.94       3.20 ± 0.77
# ...

# %% [markdown]
# # IMLIB vs DI-IMLIB vs Decision Tree (Holdout)

# %%
show_results_ho(
    ['imlib', 'diimlib', 'decision_tree'], 
    ['lung_cancer', 'iris', 'parkinsons','ionosphere','wdbc', 'transfusion', 'pima', 'titanic', 'depressed', 'mushroom']
)
# Out:
#        Datasets         Models Number of rules   |R| Largest rule size  \
# 0   lung_cancer          imlib            3.00  3.00              1.00
# 1   lung_cancer        diimlib            2.00  5.00              3.00
# 2   lung_cancer  decision_tree            2.00  2.00              1.00
# 3          iris          imlib            1.00  4.00              4.00
# 4          iris        diimlib            1.00  3.00              3.00
# 5          iris  decision_tree            4.00  9.00              3.00
# 6    parkinsons          imlib            2.00  2.00              1.00
# 7    parkinsons        diimlib            1.00  2.00              2.00
# 8    parkinsons  decision_tree            4.00  8.00              2.00
# 9    ionosphere          imlib            1.00  2.00              2.00
# 10   ionosphere        diimlib            2.00  5.00              3.00
# 11   ionosphere  decision_tree            3.00  5.00              2.00
# ...
