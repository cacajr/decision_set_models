# %%
import sys, os
if not sys.path[0] == os.path.abspath('..'):
    sys.path.insert(0, os.path.abspath('..'))

import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from utils.functions import tree_to_dnf


# 1. Load data
Xy = pd.read_csv('../databases/wdbc.csv')

X = Xy.drop(['Class'], axis=1)
y = Xy['Class']

features = X.columns
classes = y.replace({1: 'cancer', 0: 'Not cancer'}, inplace=False).unique()

# %%
# 2. Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=21)

# %%
# 3. Create a decision tree model
# Control complexity with parameters like max_depth
dt_classifier = DecisionTreeClassifier(max_leaf_nodes=3, max_depth=4, random_state=1)

# 4. Train the model
dt_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, max_leaf_nodes=3, random_state=1)

# %%
# 5. Make predictions
y_pred = dt_classifier.predict(X_test)

# 6. Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.94

# %%
# 7. Visualize the tree
plt.figure(figsize=(12, 8))
plot_tree(dt_classifier, feature_names=features, class_names=classes, filled=True)
plt.show()

# %%
dnf_clauses = tree_to_dnf(dt_classifier, features, classes, class_label='cancer')
dnf_clauses
# Out:
# [['largest radius <= 16.7950', 'largest concave points <= 0.1563']]

# %%
from models.di_imlib import DI_IMLIB

diimlib_classifier = DI_IMLIB(
    max_rule_set_size=3,
    max_size_each_rule=4,
    categorical_columns_index=[],
    number_quantiles_ordinal_columns=2,
    number_lines_per_partition=8,
    rules_accuracy_weight=10,
    balance_instances=True,
    balance_instances_seed=1
)

diimlib_classifier.fit(X_train, y_train)

accuracy = diimlib_classifier.score(X_test, y_test)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.69

# %%
diimlib_classifier.get_rules()
# Out:
# '(perimeter SE > 2.309 and concavity SE > 0.026335 and largest radius > 14.905000000000001) or (concavity SE <= 0.026335 and symmetry SE <= 0.018525 and largest area <= 682.0) or (area SE > 24.425 and concavity SE <= 0.026335 and concave points SE <= 0.01105 and largest area > 682.0)'
